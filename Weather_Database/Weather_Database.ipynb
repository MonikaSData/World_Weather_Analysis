# agva
# florence
# tevaitoa
# zyryanka
# turukhansk
# taywarah
# poronaysk
# ambon
# omboue
# jardim
# ternate
# buin
# coahuayana
# chanika
# lucapa
# yirol
# faro
# kisangani
# cabedelo
# andselv
# borovoy
# talas
# ayorou
# port pirie
# tarko-sale
# celestun
# lata
# kloulklubed
# port-cartier
# hihifo
# mitsamiouli
# port hardy
# takahagi
# imeni babushkina
# santa barbara
# pangody
# la tuque
# santa rosa
# comodoro rivadavia
# komsomolskiy
# miastko
# magadan
# saint-leu
# sambava
# plettenberg bay
# la maddalena
# elesbao veloso
# vanimo
# coihaique
# ghanzi
# sumenep
# 761

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
       # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | mishkino
# Processing Record 3 of Set 1 | gat
# Processing Record 4 of Set 1 | chuy
# Processing Record 5 of Set 1 | port lincoln
# Processing Record 6 of Set 1 | sacama
# Processing Record 7 of Set 1 | ouegoa
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | tura
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 1 | chilca
# Processing Record 14 of Set 1 | yulara
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | balkhash
# Processing Record 17 of Set 1 | lebu
# Processing Record 18 of Set 1 | riyadh
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | juan aldama
# Processing Record 21 of Set 1 | porto novo
# Processing Record 22 of Set 1 | pesaro
# Processing Record 23 of Set 1 | bognor regis
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | fare
# Processing Record 26 of Set 1 | lompoc
# Processing Record 27 of Set 1 | meulaboh
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | san patricio
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | santa engracia
# Processing Record 33 of Set 1 | terney
# Processing Record 34 of Set 1 | arlit
# Processing Record 35 of Set 1 | luderitz
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | terenos
# Processing Record 38 of Set 1 | brugg
# Processing Record 39 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 40 of Set 1 | gulf gate estates
# Processing Record 41 of Set 1 | alice springs
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | shaunavon
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | naze
# Processing Record 48 of Set 1 | cherskiy
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | cockburn town
# Processing Record 1 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 2 | saint-paul
# Processing Record 3 of Set 2 | dawson creek
# Processing Record 4 of Set 2 | ancud
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | morondava
# Processing Record 7 of Set 2 | atar
# Processing Record 8 of Set 2 | muisne
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | pisco
# Processing Record 11 of Set 2 | villa constitucion
# Processing Record 12 of Set 2 | khani
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | maiduguri
# Processing Record 15 of Set 2 | pangnirtung
# Processing Record 16 of Set 2 | alta floresta
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 2 | hobyo
# Processing Record 21 of Set 2 | port-gentil
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | sorland
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | acapulco
# Processing Record 27 of Set 2 | lagoa
# Processing Record 28 of Set 2 | chicama
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | berezovka
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | nemuro
# Processing Record 35 of Set 2 | vestmannaeyjar
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | ola
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | samarai
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 2 | paamiut
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | mareeba
# Processing Record 46 of Set 2 | gilgit
# Processing Record 47 of Set 2 | iqaluit
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | sinjar
# Processing Record 50 of Set 2 | rawson
# Processing Record 1 of Set 3 | amnat charoen
# Processing Record 2 of Set 3 | ilebo
# Processing Record 3 of Set 3 | benguela
# Processing Record 4 of Set 3 | beringovskiy
# Processing Record 5 of Set 3 | faanui
# Processing Record 6 of Set 3 | ilulissat
# Processing Record 7 of Set 3 | ust-kut
# Processing Record 8 of Set 3 | belle fourche
# Processing Record 9 of Set 3 | gao
# Processing Record 10 of Set 3 | salalah
# Processing Record 11 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 3 | lingao
# Processing Record 13 of Set 3 | margate
# Processing Record 14 of Set 3 | sao joao da barra
# Processing Record 15 of Set 3 | mount gambier
# Processing Record 16 of Set 3 | kokkola
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | tuktoyaktuk
# Processing Record 19 of Set 3 | trairi
# Processing Record 20 of Set 3 | makhinjauri
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | koumac
# Processing Record 23 of Set 3 | wernigerode
# Processing Record 24 of Set 3 | takoradi
# Processing Record 25 of Set 3 | guerrero negro
# Processing Record 26 of Set 3 | vaini
# Processing Record 27 of Set 3 | rosarito
# Processing Record 28 of Set 3 | new norfolk
# Processing Record 29 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 30 of Set 3 | liepaja
# Processing Record 31 of Set 3 | bambous virieux
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | vreed en hoop
# City not found. Skipping...
# Processing Record 34 of Set 3 | albany
# Processing Record 35 of Set 3 | asau
# Processing Record 36 of Set 3 | friesoythe
# Processing Record 37 of Set 3 | havre-saint-pierre
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | blyth
# Processing Record 40 of Set 3 | gravdal
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | big rapids
# Processing Record 43 of Set 3 | dwarka
# Processing Record 44 of Set 3 | kudahuvadhoo
# Processing Record 45 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 3 | ituporanga
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | ahipara
# Processing Record 49 of Set 3 | tacna
# Processing Record 50 of Set 3 | aksha
# Processing Record 1 of Set 4 | teguldet
# Processing Record 2 of Set 4 | coquimbo
# Processing Record 3 of Set 4 | scarborough
# Processing Record 4 of Set 4 | turayf
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | tuatapere
# Processing Record 7 of Set 4 | walvis bay
# Processing Record 8 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 4 | lorengau
# Processing Record 10 of Set 4 | ulladulla
# Processing Record 11 of Set 4 | yellowknife
# Processing Record 12 of Set 4 | tebingtinggi
# Processing Record 13 of Set 4 | matagami
# Processing Record 14 of Set 4 | aklavik
# Processing Record 15 of Set 4 | charagua
# Processing Record 16 of Set 4 | kahului
# Processing Record 17 of Set 4 | codrington
# Processing Record 18 of Set 4 | yar-sale
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | upernavik
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | xuddur
# Processing Record 24 of Set 4 | richards bay
# Processing Record 25 of Set 4 | clarksdale
# Processing Record 26 of Set 4 | severo-kurilsk
# Processing Record 27 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 28 of Set 4 | aasiaat
# Processing Record 29 of Set 4 | esperance
# Processing Record 30 of Set 4 | sinnamary
# Processing Record 31 of Set 4 | bredasdorp
# Processing Record 32 of Set 4 | maceio
# Processing Record 33 of Set 4 | wangqing
# Processing Record 34 of Set 4 | stykkisholmur
# Processing Record 35 of Set 4 | saskylakh
# Processing Record 36 of Set 4 | buraydah
# Processing Record 37 of Set 4 | taksimo
# Processing Record 38 of Set 4 | dikson
# Processing Record 39 of Set 4 | roald
# Processing Record 40 of Set 4 | mar del plata
# Processing Record 41 of Set 4 | ribeira grande
# Processing Record 42 of Set 4 | general delgado
# Processing Record 43 of Set 4 | campbellton
# Processing Record 44 of Set 4 | puerto ayora
# Processing Record 45 of Set 4 | busembatia
# Processing Record 46 of Set 4 | baker city
# Processing Record 47 of Set 4 | otofuke
# Processing Record 48 of Set 4 | wilmington
# Processing Record 49 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 4 | grindavik
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | constitucion
# Processing Record 3 of Set 5 | gondar
# Processing Record 4 of Set 5 | high level
# Processing Record 5 of Set 5 | portland
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | vostok
# Processing Record 8 of Set 5 | fuyu
# Processing Record 9 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 5 | waddan
# Processing Record 11 of Set 5 | puerto escondido
# Processing Record 12 of Set 5 | mahebourg
# Processing Record 13 of Set 5 | bogalusa
# Processing Record 14 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 15 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 5 | tamasopo
# Processing Record 17 of Set 5 | yuksekova
# Processing Record 18 of Set 5 | saint george
# Processing Record 19 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 5 | leningradskiy
# Processing Record 21 of Set 5 | lanquin
# Processing Record 22 of Set 5 | fairbanks
# Processing Record 23 of Set 5 | bud
# Processing Record 24 of Set 5 | touros
# Processing Record 25 of Set 5 | airai
# Processing Record 26 of Set 5 | sibolga
# Processing Record 27 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 30 of Set 5 | cao bang
# Processing Record 31 of Set 5 | hofn
# Processing Record 32 of Set 5 | kichera
# Processing Record 33 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 5 | carbonia
# Processing Record 35 of Set 5 | puerto colombia
# Processing Record 36 of Set 5 | port hawkesbury
# Processing Record 37 of Set 5 | marsh harbour
# Processing Record 38 of Set 5 | elizabeth city
# Processing Record 39 of Set 5 | lundazi
# Processing Record 40 of Set 5 | kaitangata
# Processing Record 41 of Set 5 | zhigansk
# Processing Record 42 of Set 5 | vila velha
# Processing Record 43 of Set 5 | qaqortoq
# Processing Record 44 of Set 5 | kimbe
# Processing Record 45 of Set 5 | saint-pierre
# Processing Record 46 of Set 5 | falkenberg
# Processing Record 47 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | mackay
# Processing Record 49 of Set 5 | sitka
# Processing Record 50 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 6 | bandarban
# Processing Record 2 of Set 6 | penha
# Processing Record 3 of Set 6 | valparaiso
# Processing Record 4 of Set 6 | rio grande
# Processing Record 5 of Set 6 | zhanaozen
# Processing Record 6 of Set 6 | billings
# Processing Record 7 of Set 6 | isangel
# Processing Record 8 of Set 6 | little current
# Processing Record 9 of Set 6 | te anau
# Processing Record 10 of Set 6 | bogorodskoye
# Processing Record 11 of Set 6 | ostrovnoy
# Processing Record 12 of Set 6 | saldanha
# Processing Record 13 of Set 6 | miramar
# Processing Record 14 of Set 6 | assiniboia
# Processing Record 15 of Set 6 | prince rupert
# Processing Record 16 of Set 6 | sao jose da coroa grande
# Processing Record 17 of Set 6 | de-kastri
# Processing Record 18 of Set 6 | nishihara
# Processing Record 19 of Set 6 | arrecife
# Processing Record 20 of Set 6 | florianopolis
# Processing Record 21 of Set 6 | leshukonskoye
# Processing Record 22 of Set 6 | san quintin
# Processing Record 23 of Set 6 | cayenne
# Processing Record 24 of Set 6 | dutse
# Processing Record 25 of Set 6 | batticaloa
# Processing Record 26 of Set 6 | iracoubo
# Processing Record 27 of Set 6 | golden
# Processing Record 28 of Set 6 | burnie
# Processing Record 29 of Set 6 | brae
# Processing Record 30 of Set 6 | uray
# Processing Record 31 of Set 6 | christchurch
# Processing Record 32 of Set 6 | thompson
# Processing Record 33 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 6 | torres
# Processing Record 35 of Set 6 | kieta
# Processing Record 36 of Set 6 | mananara
# Processing Record 37 of Set 6 | pacific grove
# Processing Record 38 of Set 6 | saint-philippe
# Processing Record 39 of Set 6 | balikpapan
# Processing Record 40 of Set 6 | rocha
# Processing Record 41 of Set 6 | joshimath
# Processing Record 42 of Set 6 | ranau
# Processing Record 43 of Set 6 | juba
# Processing Record 44 of Set 6 | araouane
# Processing Record 45 of Set 6 | la fria
# Processing Record 46 of Set 6 | mtwara
# Processing Record 47 of Set 6 | atambua
# Processing Record 48 of Set 6 | burgeo
# Processing Record 49 of Set 6 | tiznit
# Processing Record 50 of Set 6 | bechem
# Processing Record 1 of Set 7 | nowy dwor gdanski
# Processing Record 2 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 7 | college
# Processing Record 4 of Set 7 | snezhnogorsk
# Processing Record 5 of Set 7 | mackenzie
# Processing Record 6 of Set 7 | cairns
# Processing Record 7 of Set 7 | mvuma
# Processing Record 8 of Set 7 | hambantota
# Processing Record 9 of Set 7 | zvishavane
# Processing Record 10 of Set 7 | ous
# Processing Record 11 of Set 7 | brokopondo
# Processing Record 12 of Set 7 | vaijapur
# Processing Record 13 of Set 7 | porohy
# Processing Record 14 of Set 7 | katangli
# Processing Record 15 of Set 7 | shizunai
# Processing Record 16 of Set 7 | olsztyn
# Processing Record 17 of Set 7 | sechura
# Processing Record 18 of Set 7 | ikwiriri
# Processing Record 19 of Set 7 | winnipeg
# Processing Record 20 of Set 7 | beyneu
# Processing Record 21 of Set 7 | port blair
# Processing Record 22 of Set 7 | rio gallegos
# Processing Record 23 of Set 7 | deputatskiy
# Processing Record 24 of Set 7 | tiksi
# Processing Record 25 of Set 7 | amahai
# Processing Record 26 of Set 7 | buenos aires
# Processing Record 27 of Set 7 | along
# Processing Record 28 of Set 7 | katsuura
# Processing Record 29 of Set 7 | dalian
# Processing Record 30 of Set 7 | belmonte
# Processing Record 31 of Set 7 | kidal
# Processing Record 32 of Set 7 | santa ana
# Processing Record 33 of Set 7 | danielskuil
# Processing Record 34 of Set 7 | tautira
# Processing Record 35 of Set 7 | ajdabiya
# Processing Record 36 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 7 | uaua
# Processing Record 38 of Set 7 | sao filipe
# Processing Record 39 of Set 7 | kincardine
# Processing Record 40 of Set 7 | mpulungu
# Processing Record 41 of Set 7 | trenggalek
# Processing Record 42 of Set 7 | mapiripan
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | astana
# Processing Record 45 of Set 7 | teya
# Processing Record 46 of Set 7 | diamantino
# Processing Record 47 of Set 7 | ulcinj
# Processing Record 48 of Set 7 | balakirevo
# Processing Record 49 of Set 7 | yerbogachen
# Processing Record 50 of Set 7 | hami
# Processing Record 1 of Set 8 | rio grande city
# Processing Record 2 of Set 8 | luanda
# Processing Record 3 of Set 8 | anshun
# Processing Record 4 of Set 8 | sept-iles
# Processing Record 5 of Set 8 | sioux lookout
# Processing Record 6 of Set 8 | santa rosalia
# Processing Record 7 of Set 8 | sidrolandia
# Processing Record 8 of Set 8 | aitape
# Processing Record 9 of Set 8 | north bend
# Processing Record 10 of Set 8 | udachnyy
# Processing Record 11 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 8 | villarrica
# Processing Record 13 of Set 8 | umm kaddadah
# Processing Record 14 of Set 8 | camana
# Processing Record 15 of Set 8 | kemijarvi
# Processing Record 16 of Set 8 | dalbandin
# Processing Record 17 of Set 8 | anaconda
# Processing Record 18 of Set 8 | banepa
# Processing Record 19 of Set 8 | bartica
# Processing Record 20 of Set 8 | dekoa
# City not found. Skipping...
# Processing Record 21 of Set 8 | borgo san lorenzo
# Processing Record 22 of Set 8 | bambanglipuro
# Processing Record 23 of Set 8 | lubbock
# Processing Record 24 of Set 8 | roma
# Processing Record 25 of Set 8 | vila franca do campo
# Processing Record 26 of Set 8 | cidreira
# Processing Record 27 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 8 | pochutla
# Processing Record 29 of Set 8 | azrow
# City not found. Skipping...
# Processing Record 30 of Set 8 | moquegua
# Processing Record 31 of Set 8 | yamada
# Processing Record 32 of Set 8 | isla mujeres
# Processing Record 33 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 34 of Set 8 | bell ville
# Processing Record 35 of Set 8 | kalevala
# Processing Record 36 of Set 8 | trunovskoye
# Processing Record 37 of Set 8 | sakata
# Processing Record 38 of Set 8 | merida
# Processing Record 39 of Set 8 | yeniseysk
# Processing Record 40 of Set 8 | tahe
# Processing Record 41 of Set 8 | srednekolymsk
# Processing Record 42 of Set 8 | kuzino
# Processing Record 43 of Set 8 | kasongo-lunda
# Processing Record 44 of Set 8 | san remo
# Processing Record 45 of Set 8 | bergen
# Processing Record 46 of Set 8 | hamilton
# Processing Record 47 of Set 8 | nchelenge
# Processing Record 48 of Set 8 | vanderhoof
# Processing Record 49 of Set 8 | flinders
# Processing Record 50 of Set 8 | quang ngai
# Processing Record 1 of Set 9 | tual
# Processing Record 2 of Set 9 | madang
# Processing Record 3 of Set 9 | mayo
# Processing Record 4 of Set 9 | konya
# Processing Record 5 of Set 9 | viedma
# Processing Record 6 of Set 9 | hasaki
# Processing Record 7 of Set 9 | mazyr
# Processing Record 8 of Set 9 | toyooka
# Processing Record 9 of Set 9 | caravelas
# Processing Record 10 of Set 9 | dombarovskiy
# Processing Record 11 of Set 9 | luwuk
# Processing Record 12 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 13 of Set 9 | tres arroyos
# Processing Record 14 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 15 of Set 9 | road town
# Processing Record 16 of Set 9 | petukhovo
# Processing Record 17 of Set 9 | nawa
# Processing Record 18 of Set 9 | aksu
# Processing Record 19 of Set 9 | inverell
# Processing Record 20 of Set 9 | conde
# Processing Record 21 of Set 9 | sausar
# Processing Record 22 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 9 | avera
# Processing Record 24 of Set 9 | taoudenni
# Processing Record 25 of Set 9 | amboasary
# Processing Record 26 of Set 9 | gorom-gorom
# Processing Record 27 of Set 9 | stulovo
# Processing Record 28 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 9 | skjervoy
# Processing Record 30 of Set 9 | helena
# Processing Record 31 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 32 of Set 9 | mukhen
# Processing Record 33 of Set 9 | jiuquan
# Processing Record 34 of Set 9 | longkou
# Processing Record 35 of Set 9 | killybegs
# Processing Record 36 of Set 9 | clyde river
# Processing Record 37 of Set 9 | bethel
# Processing Record 38 of Set 9 | korla
# Processing Record 39 of Set 9 | bereda
# Processing Record 40 of Set 9 | baruun-urt
# Processing Record 41 of Set 9 | katete
# Processing Record 42 of Set 9 | kavaratti
# Processing Record 43 of Set 9 | noumea
# Processing Record 44 of Set 9 | salamiyah
# Processing Record 45 of Set 9 | bathsheba
# Processing Record 46 of Set 9 | obidos
# Processing Record 47 of Set 9 | kendari
# Processing Record 48 of Set 9 | vardo
# Processing Record 49 of Set 9 | valkeakoski
# Processing Record 50 of Set 9 | marovoay
# Processing Record 1 of Set 10 | kilindoni
# Processing Record 2 of Set 10 | nanortalik
# Processing Record 3 of Set 10 | olinda
# Processing Record 4 of Set 10 | dingle
# Processing Record 5 of Set 10 | torrington
# Processing Record 6 of Set 10 | kirakira
# Processing Record 7 of Set 10 | mlandizi
# Processing Record 8 of Set 10 | ongandjera
# Processing Record 9 of Set 10 | talnakh
# Processing Record 10 of Set 10 | riorges
# Processing Record 11 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 10 | asfi
# Processing Record 13 of Set 10 | kaniama
# Processing Record 14 of Set 10 | vuktyl
# Processing Record 15 of Set 10 | lavrentiya
# Processing Record 16 of Set 10 | dvinskoy
# Processing Record 17 of Set 10 | kanigoro
# Processing Record 18 of Set 10 | bose
# Processing Record 19 of Set 10 | bilma
# Processing Record 20 of Set 10 | sivas
# Processing Record 21 of Set 10 | boende
# Processing Record 22 of Set 10 | san ramon
# Processing Record 23 of Set 10 | saint anthony
# Processing Record 24 of Set 10 | tres lagoas
# Processing Record 25 of Set 10 | tamworth
# Processing Record 26 of Set 10 | diffa
# Processing Record 27 of Set 10 | aswan
# Processing Record 28 of Set 10 | modasa
# Processing Record 29 of Set 10 | sembakung
# Processing Record 30 of Set 10 | karratha
# Processing Record 31 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 32 of Set 10 | maragogi
# Processing Record 33 of Set 10 | conway
# Processing Record 34 of Set 10 | sur
# Processing Record 35 of Set 10 | nizwa
# Processing Record 36 of Set 10 | sultanpur
# Processing Record 37 of Set 10 | luzhou
# Processing Record 38 of Set 10 | witu
# Processing Record 39 of Set 10 | batemans bay
# Processing Record 40 of Set 10 | krasnokamensk
# Processing Record 41 of Set 10 | north myrtle beach
# Processing Record 42 of Set 10 | birjand
# Processing Record 43 of Set 10 | povenets
# Processing Record 44 of Set 10 | ambilobe
# Processing Record 45 of Set 10 | wewak
# Processing Record 46 of Set 10 | praia da vitoria
# Processing Record 47 of Set 10 | labuhan
# Processing Record 48 of Set 10 | dzhebariki-khaya
# Processing Record 49 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 10 | gashua
# Processing Record 1 of Set 11 | fukue
# Processing Record 2 of Set 11 | mantua
# Processing Record 3 of Set 11 | kamenka
# Processing Record 4 of Set 11 | bonavista
# Processing Record 5 of Set 11 | suozhen
# Processing Record 6 of Set 11 | dunedin
# Processing Record 7 of Set 11 | kodiak
# Processing Record 8 of Set 11 | tabuk
# Processing Record 9 of Set 11 | bosansko grahovo
# Processing Record 10 of Set 11 | plougastel-daoulas
# Processing Record 11 of Set 11 | camacha
# Processing Record 12 of Set 11 | ossora
# Processing Record 13 of Set 11 | catamarca
# Processing Record 14 of Set 11 | derzhavinsk
# Processing Record 15 of Set 11 | concarneau
# Processing Record 16 of Set 11 | manicore
# Processing Record 17 of Set 11 | pucallpa
# Processing Record 18 of Set 11 | troitskoye
# Processing Record 19 of Set 11 | porangatu
# Processing Record 20 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 21 of Set 11 | san cristobal
# Processing Record 22 of Set 11 | xining
# Processing Record 23 of Set 11 | port hedland
# Processing Record 24 of Set 11 | jalingo
# Processing Record 25 of Set 11 | bolshaya irba
# City not found. Skipping...
# Processing Record 26 of Set 11 | yunyang
# Processing Record 27 of Set 11 | lasa
# Processing Record 28 of Set 11 | san jose de las lajas
# Processing Record 29 of Set 11 | akyab
# Processing Record 30 of Set 11 | terrace
# Processing Record 31 of Set 11 | bogyiszlo
# Processing Record 32 of Set 11 | homer
# Processing Record 33 of Set 11 | ipixuna
# Processing Record 34 of Set 11 | tanete
# Processing Record 35 of Set 11 | mandalgovi
# Processing Record 36 of Set 11 | husavik
# Processing Record 37 of Set 11 | bahar
# Processing Record 38 of Set 11 | broken hill
# Processing Record 39 of Set 11 | virginia beach
# Processing Record 40 of Set 11 | haines junction
# Processing Record 41 of Set 11 | eyl
# Processing Record 42 of Set 11 | beloha
# Processing Record 43 of Set 11 | hualmay
# Processing Record 44 of Set 11 | caririacu
# Processing Record 45 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 46 of Set 11 | synya
# Processing Record 47 of Set 11 | borinskoye
# Processing Record 48 of Set 11 | chapais
# Processing Record 49 of Set 11 | vozhd proletariata
# City not found. Skipping...
# Processing Record 50 of Set 11 | adre
# Processing Record 1 of Set 12 | bairiki
# Processing Record 2 of Set 12 | saint-augustin
# Processing Record 3 of Set 12 | makakilo city
# Processing Record 4 of Set 12 | berdigestyakh
# Processing Record 5 of Set 12 | salinas
# Processing Record 6 of Set 12 | banikoara
# Processing Record 7 of Set 12 | kushmurun
# Processing Record 8 of Set 12 | savannah bight
# Processing Record 9 of Set 12 | torbay
# Processing Record 10 of Set 12 | limbang
# Processing Record 11 of Set 12 | alekseyevskaya
# Processing Record 12 of Set 12 | jinchang
# Processing Record 13 of Set 12 | hervey bay
# Processing Record 14 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 15 of Set 12 | huntley
# Processing Record 16 of Set 12 | songjianghe
# Processing Record 17 of Set 12 | boddam
# Processing Record 18 of Set 12 | lixourion
# Processing Record 19 of Set 12 | tahta
# Processing Record 20 of Set 12 | malakal
# Processing Record 21 of Set 12 | buala
# Processing Record 22 of Set 12 | chaibasa
# Processing Record 23 of Set 12 | marawi
# Processing Record 24 of Set 12 | waipawa
# Processing Record 25 of Set 12 | svetlogorsk
# Processing Record 26 of Set 12 | passos
# Processing Record 27 of Set 12 | atbasar
# Processing Record 28 of Set 12 | calvinia
# Processing Record 29 of Set 12 | whitianga
# Processing Record 30 of Set 12 | teguise
# Processing Record 31 of Set 12 | tilichiki
# Processing Record 32 of Set 12 | soyo
# Processing Record 33 of Set 12 | bubaque
# Processing Record 34 of Set 12 | gagra
# Processing Record 35 of Set 12 | grand gaube
# Processing Record 36 of Set 12 | hay river
# Processing Record 37 of Set 12 | rolla
# Processing Record 38 of Set 12 | alyangula
# Processing Record 39 of Set 12 | cabra
# Processing Record 40 of Set 12 | mount isa
# Processing Record 41 of Set 12 | gurmatkal
# Processing Record 42 of Set 12 | andapa
# Processing Record 43 of Set 12 | maryville
# Processing Record 44 of Set 12 | vung tau
# Processing Record 45 of Set 12 | galle
# Processing Record 46 of Set 12 | ketchikan
# Processing Record 47 of Set 12 | cortez
# Processing Record 48 of Set 12 | tocopilla
# Processing Record 49 of Set 12 | male
# Processing Record 50 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 1 of Set 13 | mae ramat
# Processing Record 2 of Set 13 | broome
# Processing Record 3 of Set 13 | wuhan
# Processing Record 4 of Set 13 | gazanjyk
# Processing Record 5 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 6 of Set 13 | nagar karnul
# Processing Record 7 of Set 13 | nara
# Processing Record 8 of Set 13 | emba
# Processing Record 9 of Set 13 | necochea
# Processing Record 10 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 11 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 13 | kautokeino
# Processing Record 13 of Set 13 | beira
# Processing Record 14 of Set 13 | vastervik
# City not found. Skipping...
# Processing Record 15 of Set 13 | zhangye
# Processing Record 16 of Set 13 | nouadhibou
# Processing Record 17 of Set 13 | adrar
# Processing Record 18 of Set 13 | dolgorukovo
# Processing Record 19 of Set 13 | belaya gora
# Processing Record 20 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 13 | taganak
# Processing Record 23 of Set 13 | okha
# Processing Record 24 of Set 13 | aktau
# Processing Record 25 of Set 13 | macapa
# Processing Record 26 of Set 13 | darhan
# Processing Record 27 of Set 13 | hongjiang
# Processing Record 28 of Set 13 | moose factory
# Processing Record 29 of Set 13 | soe
# Processing Record 30 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 13 | goderich
# Processing Record 32 of Set 13 | brownwood
# Processing Record 33 of Set 13 | polis
# Processing Record 34 of Set 13 | burica
# City not found. Skipping...
# Processing Record 35 of Set 13 | stockach
# Processing Record 36 of Set 13 | middelburg
# Processing Record 37 of Set 13 | skeldon
# Processing Record 38 of Set 13 | ishigaki
# Processing Record 39 of Set 13 | falmouth
# Processing Record 40 of Set 13 | mabaruma
# Processing Record 41 of Set 13 | kalmunai
# Processing Record 42 of Set 13 | jibuti
# Processing Record 43 of Set 13 | hukeri
# Processing Record 44 of Set 13 | yarim
# Processing Record 45 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 13 | jalor
# Processing Record 47 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 13 | swan river
# Processing Record 49 of Set 13 | pandan
# Processing Record 50 of Set 13 | shitanjing
# Processing Record 1 of Set 14 | nicoya
# Processing Record 2 of Set 14 | praia
# Processing Record 3 of Set 14 | odessa
# Processing Record 4 of Set 14 | mayumba
# Processing Record 5 of Set 14 | tete
# Processing Record 6 of Set 14 | laguna
# Processing Record 7 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 14 | los llanos de aridane
# Processing Record 9 of Set 14 | portree
# Processing Record 10 of Set 14 | juazeiro
# Processing Record 11 of Set 14 | anzio
# Processing Record 12 of Set 14 | altay
# Processing Record 13 of Set 14 | vikulovo
# Processing Record 14 of Set 14 | esso
# Processing Record 15 of Set 14 | auki
# Processing Record 16 of Set 14 | trogir
# Processing Record 17 of Set 14 | muros
# Processing Record 18 of Set 14 | novobelokatay
# Processing Record 19 of Set 14 | madimba
# Processing Record 20 of Set 14 | abeche
# Processing Record 21 of Set 14 | malvern
# Processing Record 22 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 23 of Set 14 | khonsa
# Processing Record 24 of Set 14 | corinth
# Processing Record 25 of Set 14 | timizart
# Processing Record 26 of Set 14 | novyy urengoy
# Processing Record 27 of Set 14 | buta
# Processing Record 28 of Set 14 | waingapu
# Processing Record 29 of Set 14 | kondoa
# Processing Record 30 of Set 14 | arman
# Processing Record 31 of Set 14 | katol
# Processing Record 32 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 33 of Set 14 | damaturu
# Processing Record 34 of Set 14 | truro
# Processing Record 35 of Set 14 | kez
# Processing Record 36 of Set 14 | muzhi
# Processing Record 37 of Set 14 | ranfurly
# Processing Record 38 of Set 14 | yenagoa
# Processing Record 39 of Set 14 | najran
# Processing Record 40 of Set 14 | fez
# Processing Record 41 of Set 14 | strelka
# Processing Record 42 of Set 14 | pueblo nuevo
# Processing Record 43 of Set 14 | ulaangom
# Processing Record 44 of Set 14 | guanica
# Processing Record 45 of Set 14 | nabire
# Processing Record 46 of Set 14 | sumter
# Processing Record 47 of Set 14 | ust-omchug
# Processing Record 48 of Set 14 | goleta
# Processing Record 49 of Set 14 | namibe
# Processing Record 50 of Set 14 | aberfeldy
# Processing Record 1 of Set 15 | lakes entrance
# Processing Record 2 of Set 15 | tucuma
# Processing Record 3 of Set 15 | wonosobo
# Processing Record 4 of Set 15 | carutapera
# Processing Record 5 of Set 15 | mingaora
# Processing Record 6 of Set 15 | erenhot
# Processing Record 7 of Set 15 | corinto
# Processing Record 8 of Set 15 | moron
# Processing Record 9 of Set 15 | kattivakkam
# Processing Record 10 of Set 15 | iquique
# Processing Record 11 of Set 15 | agva
# City not found. Skipping...
# Processing Record 12 of Set 15 | florence
# Processing Record 13 of Set 15 | tevaitoa
# Processing Record 14 of Set 15 | zyryanka
# Processing Record 15 of Set 15 | turukhansk
# Processing Record 16 of Set 15 | taywarah
# Processing Record 17 of Set 15 | poronaysk
# Processing Record 18 of Set 15 | ambon
# Processing Record 19 of Set 15 | omboue
# Processing Record 20 of Set 15 | jardim
# Processing Record 21 of Set 15 | ternate
# Processing Record 22 of Set 15 | buin
# Processing Record 23 of Set 15 | coahuayana
# Processing Record 24 of Set 15 | chanika
# Processing Record 25 of Set 15 | lucapa
# Processing Record 26 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 27 of Set 15 | faro
# Processing Record 28 of Set 15 | kisangani
# Processing Record 29 of Set 15 | cabedelo
# Processing Record 30 of Set 15 | andselv
# City not found. Skipping...
# Processing Record 31 of Set 15 | borovoy
# Processing Record 32 of Set 15 | talas
# Processing Record 33 of Set 15 | ayorou
# Processing Record 34 of Set 15 | port pirie
# Processing Record 35 of Set 15 | tarko-sale
# Processing Record 36 of Set 15 | celestun
# Processing Record 37 of Set 15 | lata
# Processing Record 38 of Set 15 | kloulklubed
# Processing Record 39 of Set 15 | port-cartier
# Processing Record 40 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 15 | mitsamiouli
# Processing Record 42 of Set 15 | port hardy
# Processing Record 43 of Set 15 | takahagi
# Processing Record 44 of Set 15 | imeni babushkina
# Processing Record 45 of Set 15 | santa barbara
# Processing Record 46 of Set 15 | pangody
# Processing Record 47 of Set 15 | la tuque
# Processing Record 48 of Set 15 | santa rosa
# Processing Record 49 of Set 15 | comodoro rivadavia
# Processing Record 50 of Set 15 | komsomolskiy
# Processing Record 1 of Set 16 | miastko
# Processing Record 2 of Set 16 | magadan
# Processing Record 3 of Set 16 | saint-leu
# Processing Record 4 of Set 16 | sambava
# Processing Record 5 of Set 16 | plettenberg bay
# Processing Record 6 of Set 16 | la maddalena
# Processing Record 7 of Set 16 | elesbao veloso
# Processing Record 8 of Set 16 | vanimo
# Processing Record 9 of Set 16 | coihaique
# Processing Record 10 of Set 16 | ghanzi
# Processing Record 11 of Set 16 | sumenep
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng      Description  Max Temp  Humidity  \
# 0       Mataura -46.1927  168.8643       light rain     60.01        56
# 1      Mishkino  55.3389   63.9175        clear sky     -1.95        90
# 2           Gat  31.6100   34.7642    moderate rain     55.00       100
# 3          Chuy -33.6971  -53.4616    broken clouds     71.42        60
# 4  Port Lincoln -34.7333  135.8667  overcast clouds     60.39        77
# 5        Sacama  -3.9000  -79.2667    moderate rain     77.00        61
# 6        Ouegoa -20.3500  164.4333       light rain     83.71        75
# 7         Kapaa  22.0752 -159.3190       few clouds     80.60        69
# 8          Tura  25.5198   90.2201        clear sky     57.61        70
# 9   East London -33.0153   27.9116  overcast clouds     70.34        71
#
#    Cloudiness  Wind Speed Country
# 0          35        8.01      NZ
# 1           0       12.06      RU
# 2          83        5.99      IL
# 3          75        9.08      UY
# 4         100       11.86      AU
# 5          75       12.66      EC
# 6          92       10.07      NC
# 7          20       19.57      US
# 8           0        3.60      IN
# 9          92        4.90      ZA

# %%
city_data_new_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description' ]
city_data_df = city_data_df[city_data_new_order]
city_data_df = city_data_df.rename(columns={"Description": "Current Description"})
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     60.01        56          35
# 1      Mishkino      RU  55.3389   63.9175     -1.95        90           0
# 2           Gat      IL  31.6100   34.7642     55.00       100          83
# 3          Chuy      UY -33.6971  -53.4616     71.42        60          75
# 4  Port Lincoln      AU -34.7333  135.8667     60.39        77         100
# 5        Sacama      EC  -3.9000  -79.2667     77.00        61          75
# 6        Ouegoa      NC -20.3500  164.4333     83.71        75          92
# 7         Kapaa      US  22.0752 -159.3190     80.60        69          20
# 8          Tura      IN  25.5198   90.2201     57.61        70           0
# 9   East London      ZA -33.0153   27.9116     70.34        71          92
#
#    Wind Speed Current Description
# 0        8.01          light rain
# 1       12.06           clear sky
# 2        5.99       moderate rain
# 3        9.08       broken clouds
# 4       11.86     overcast clouds
# 5       12.66       moderate rain
# 6       10.07          light rain
# 7       19.57          few clouds
# 8        3.60           clear sky
# 9        4.90     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
